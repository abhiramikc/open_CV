# %% [markdown]
# ## Drawing images and shapes using OpenCV
#
# Let's start off my making a black square

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
#create a black image using numpy to create and array of black
image=np.zeros((250,512,3),np.uint8)
from google.colab.patches import cv2_imshow
cv2_imshow(image)

#create gray scale image
image_bw=np.zeros((520,200),np.uint8)
cv2_imshow(image_bw)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x250 at 0x7F992273DA90>
# <PIL.Image.Image image mode=L size=200x520 at 0x7F992273D748>

# %%
# import cv2
# import numpy as np

# # Create a black image using numpy to create and array of black 
# image = np.zeros((512,512,3), np.uint8)

# # Can we make this in black and white? grayscale
# image_bw = np.zeros((512,512), np.uint8)

# # Black would be the same as a greyscale or color image (same for white)
# cv2.imshow("Black Rectangle (Color)", image)
# cv2.imshow("Black Rectangle (B&W)", image_bw)

# cv2.waitKey()
# cv2.destroyAllWindows()

# %% [markdown]
# ### Let's draw a line over our black square
#
# cv2.line(image, starting cordinates, ending cordinates, color, thickness)

# %%
# Draw a diagonal blue line of thickness of 5 pixels

# Create our black canvas again
image = np.zeros((512,512,3), np.uint8)
image=np.zeros((512,512,3),np.uint8)
cv2.line(image,(0,0),(511,511),(255,127,0),5)
cv2_imshow(image)

# cv2.line(image, (0,0), (511,511), (255,127,0), -1)
# cv2.imshow("Blue Line", image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F99226372E8>

# %% [markdown]
# ### Let's now draw a rectangle
#
# cv2.rectangle(image, starting vertex, opposite vertex, color, thickness)

# %%
# Draw a Rectangle 
image = np.zeros((512,512,3), np.uint8)

# Thickness - if positive. Negative thickness means that it is filled
cv2.rectangle(image, (100,100), (300,250), (127,50,127), 5)
cv2_imshow(image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F9922637CF8>

# %% [markdown]
# ### How about cirlcles?
#
# cv2.cirlce(image, center, radius, color, fill)

# %%
image = np.zeros((512,512,3), np.uint8)
cv2.circle(image, (350, 250), 100, (15,75,50), -1) 
cv2_imshow(image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F99225C6CC0>

# %% [markdown]
# ## And polygons?
#
# cv2.polylines(image, points, Closed?, color, thickness)
#
# if Closed = True, we join the first and last point

# %%
image = np.zeros((512,512,3), np.uint8)

# Let's define four points
pts = np.array( [[10,50], [400,50], [90,200], [50,500]], np.int32)

# Let's now reshape our points in form  required by polylines
pts = pts.reshape((-1,1,2))

cv2.polylines(image, [pts], True, (0,0,255), 3)
cv2.imshow("Polygon", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image=np.zeros((512,512,3),np.uint8)
pts=np.array([[10,50],[400,50],[90,200],[50,500]],np.int32)
pts.reshape((-1,1,2))
cv2.polylines(image,[pts],True,(111,122,123),3)
cv2_imshow(image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F9922676AC8>

# %%
pts = np.array( [[10,50], [400,50], [90,200], [50,500]], np.int32)
pts.shape
# Out:
# (4, 2)

# %%
pts = pts.reshape((-1,1,2))
pts.shape
# Out:
# (4, 1, 2)

# %% [markdown]
# ### Let's even add text with cv2.putText
#
# cv2.putText(image, 'Text to Display', bottom left starting point, Font, Font Size, Color, Thickness)
#
# - FONT_HERSHEY_SIMPLEX, FONT_HERSHEY_PLAIN
# - FONT_HERSHEY_DUPLEX,FONT_HERSHEY_COMPLEX
# - FONT_HERSHEY_TRIPLEX, FONT_HERSHEY_COMPLEX_SMALL
# - FONT_HERSHEY_SCRIPT_SIMPLEX
# - FONT_HERSHEY_SCRIPT_COMPLEX

# %%
image = np.zeros((1000,1000,3), np.uint8)
ourString =  'Hello World!'
cv2.putText(image,ourString, (155,290), cv2.FONT_HERSHEY_SIMPLEX, 3, (240,170,0), 5)
cv2_imshow(image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x7F9922855BE0>
